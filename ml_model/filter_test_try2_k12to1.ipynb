# %%
import train_model
import importlib
importlib.reload(train_model)
TrainModel = train_model.TrainModel
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf

# %%
model_training_flt_set_5 = TrainModel(epoch = 150, filter=True, poles=5, upperCutoff = 5)
model_training_flt_set_5.train_model()
model_training_flt_set_5.test_model()
sns.relplot(data=pd.DataFrame(model_training_flt_set_5.history.history), kind='line', height=4, aspect=4)
plt.show()
# Out:
# 100%|██████████| 21837/21837 [00:38<00:00, 560.18it/s]
# Epoch 1/150
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 75s 156ms/step - cat_acc: 0.3244 - f1_macro: 0.1724 - loss: 1.9881 - precision: 0.5652 - recall: 0.0032 - val_cat_acc: 0.4636 - val_f1_macro: 0.1120 - val_loss: 1.8622 - val_precision: 0.8000 - val_recall: 0.0115
# Epoch 2/150
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 60s 145ms/step - cat_acc: 0.4452 - f1_macro: 0.1454 - loss: 1.8631 - precision: 0.7308 - recall: 0.0146 - val_cat_acc: 0.4819 - val_f1_macro: 0.1966 - val_loss: 1.7795 - val_precision: 0.8659 - val_recall: 0.0893
# Epoch 3/150
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 60s 146ms/step - cat_acc: 0.4834 - f1_macro: 0.2601 - loss: 1.7772 - precision: 0.8026 - recall: 0.1188 - val_cat_acc: 0.5394 - val_f1_macro: 0.3916 - val_loss: 1.6492 - val_precision: 0.7948 - val_recall: 0.2449
# Epoch 4/150
# ...

# %%
model_training_flt_set_10 = TrainModel(epoch = 150, filter=True, poles=5, upperCutoff = 10)
model_training_flt_set_10.train_model()
model_training_flt_set_10.test_model()
sns.relplot(data=pd.DataFrame(model_training_flt_set_10.history.history), kind='line', height=4, aspect=4)
plt.show()
# Out:
# 100%|██████████| 21837/21837 [00:39<00:00, 558.14it/s]
# Epoch 1/150
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 75s 154ms/step - cat_acc: 0.2753 - f1_macro: 0.1445 - loss: 2.0262 - precision: 0.3521 - recall: 5.3825e-04 - val_cat_acc: 0.4533 - val_f1_macro: 0.1248 - val_loss: 1.8995 - val_precision: 0.7750 - val_recall: 0.0111
# Epoch 2/150
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 57s 138ms/step - cat_acc: 0.4426 - f1_macro: 0.1328 - loss: 1.8738 - precision: 0.7266 - recall: 0.0101 - val_cat_acc: 0.4583 - val_f1_macro: 0.1295 - val_loss: 1.8216 - val_precision: 0.7638 - val_recall: 0.0174
# Epoch 3/150
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 58s 142ms/step - cat_acc: 0.4525 - f1_macro: 0.1494 - loss: 1.8260 - precision: 0.7176 - recall: 0.0330 - val_cat_acc: 0.4831 - val_f1_macro: 0.1910 - val_loss: 1.7633 - val_precision: 0.7954 - val_recall: 0.1599
# Epoch 4/150
# ...

# %%
model_training_flt_set_15 = TrainModel(epoch = 250, filter=True, poles=5, upperCutoff = 15)
model_training_flt_set_15.train_model()
model_training_flt_set_15.test_model()
sns.relplot(data=pd.DataFrame(model_training_flt_set_15.history.history), kind='line', height=4, aspect=4)
plt.show()
# Out:
# 100%|██████████| 21837/21837 [00:36<00:00, 602.79it/s]
# 2025-05-24 16:57:18.801206: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2025-05-24 16:57:18.801234: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2025-05-24 16:57:18.801237: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# 2025-05-24 16:57:18.801254: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-05-24 16:57:18.801269: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/250
# ...

# %%
model_training_flt_set_20 = TrainModel(epoch = 250, filter=True, poles=5, upperCutoff = 20)
model_training_flt_set_20.train_model()
model_training_flt_set_20.test_model()
sns.relplot(data=pd.DataFrame(model_training_flt_set_20.history.history), kind='line', height=4, aspect=4)
plt.show()
# Out:
# 100%|██████████| 21837/21837 [00:33<00:00, 660.11it/s]
# Epoch 1/250
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 72s 150ms/step - cat_acc: 0.4615 - f1_macro: 0.1239 - loss: 1.9658 - precision: 0.3990 - recall: 1.8308e-04 - val_cat_acc: 0.4712 - val_f1_macro: 0.1759 - val_loss: 1.8512 - val_precision: 0.8409 - val_recall: 0.0066
# Epoch 2/250
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 57s 138ms/step - cat_acc: 0.4603 - f1_macro: 0.1837 - loss: 1.8453 - precision: 0.7685 - recall: 0.0075 - val_cat_acc: 0.4860 - val_f1_macro: 0.2058 - val_loss: 1.7878 - val_precision: 0.7050 - val_recall: 0.1069
# Epoch 3/250
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 60s 146ms/step - cat_acc: 0.4713 - f1_macro: 0.2226 - loss: 1.7870 - precision: 0.6926 - recall: 0.1137 - val_cat_acc: 0.5002 - val_f1_macro: 0.2594 - val_loss: 1.7370 - val_precision: 0.7073 - val_recall: 0.2271
# Epoch 4/250
# ...

# %%
128//2
# Out:
# 64

# %%
model_training_flt_set_25 = TrainModel(epoch = 500, filter=True, poles=5, stop_percistance= 100, upperCutoff = 25)
model_training_flt_set_25.train_model()
model_training_flt_set_25.test_model()
sns.relplot(data=pd.DataFrame(model_training_flt_set_25.history.history), kind='line', height=4, aspect=4)
plt.show()
# Out:
# 100%|██████████| 21837/21837 [00:36<00:00, 601.25it/s]
# 2025-05-24 21:11:36.297343: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2025-05-24 21:11:36.297381: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2025-05-24 21:11:36.297384: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# 2025-05-24 21:11:36.297405: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-05-24 21:11:36.297417: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/500
# ...

# %%
model_training_flt_set_30 = TrainModel(epoch = 500, filter=True, poles=5, stop_percistance= 100, upperCutoff = 30)
model_training_flt_set_30.train_model()
model_training_flt_set_30.test_model()
sns.relplot(data=pd.DataFrame(model_training_flt_set_30.history.history), kind='line', height=4, aspect=4)
plt.show()

# %%
model_training_flt_set_35 = TrainModel(epoch = 500, filter=True, poles=5, stop_percistance= 100, upperCutoff = 35)
model_training_flt_set_35.train_model()
model_training_flt_set_35.test_model()
sns.relplot(data=pd.DataFrame(model_training_flt_set_35.history.history), kind='line', height=4, aspect=4)
plt.show()

# %%
model_training_flt_set_40 = TrainModel(epoch = 500, filter=True, poles=5, stop_percistance= 100, upperCutoff = 40)
model_training_flt_set_40.train_model()
model_training_flt_set_40.test_model()
sns.relplot(data=pd.DataFrame(model_training_flt_set_40.history.history), kind='line', height=4, aspect=4)
plt.show()

# %%
model_training_flt_set_45 = TrainModel(epoch = 500, filter=True, poles=5, stop_percistance= 100, upperCutoff = 45)
model_training_flt_set_45.train_model()
model_training_flt_set_45.test_model()
sns.relplot(data=pd.DataFrame(model_training_flt_set_45.history.history), kind='line', height=4, aspect=4)
plt.show()

# %%
model_training_flt_set_50 = TrainModel(epoch = 500, filter=True, poles=5, stop_percistance= 100, upperCutoff = 49)
model_training_flt_set_50.train_model()
model_training_flt_set_50.test_model()
sns.relplot(data=pd.DataFrame(model_training_flt_set_50.history.history), kind='line', height=4, aspect=4)
plt.show()

# %% [markdown]
# - change kernal from 12 to 1
# - Add one more 16 after 2nd attention block then add another attention block
