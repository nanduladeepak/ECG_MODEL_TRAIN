# %%
import train_model
import importlib
importlib.reload(train_model)
TrainModel = train_model.TrainModel

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import tensorflow as tf

# %%
model_training = TrainModel(epoch = 150)
# Out:
# 100%|██████████| 21837/21837 [00:38<00:00, 562.52it/s]
# 2025-05-15 07:46:27.083269: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2025-05-15 07:46:27.083305: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2025-05-15 07:46:27.083308: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# 2025-05-15 07:46:27.083329: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-05-15 07:46:27.083339: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model_training.train_model()
# Out:
# Epoch 1/150
# 2025-05-15 07:46:29.939648: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 98s 213ms/step - Precision: 0.6128 - Recall: 0.0068 - accuracy: 0.0741 - binary_accuracy: 0.7457 - loss: 2.1291 - val_Precision: 0.6000 - val_Recall: 0.0027 - val_accuracy: 0.3929 - val_binary_accuracy: 0.7454 - val_loss: 1.9989
# Epoch 2/150
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 85s 207ms/step - Precision: 0.7568 - Recall: 2.8367e-04 - accuracy: 0.3733 - binary_accuracy: 0.7444 - loss: 1.9964 - val_Precision: 0.7917 - val_Recall: 0.0034 - val_accuracy: 0.4375 - val_binary_accuracy: 0.7458 - val_loss: 1.9202
# Epoch 3/150
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 85s 206ms/step - Precision: 0.6315 - Recall: 8.9708e-04 - accuracy: 0.4176 - binary_accuracy: 0.7450 - loss: 1.9210 - val_Precision: 0.8750 - val_Recall: 0.0050 - val_accuracy: 0.4599 - val_binary_accuracy: 0.7462 - val_loss: 1.8716
# ...

# %%
sns.relplot(data=pd.DataFrame(model_training.history.history), kind='line', height=4, aspect=4)
plt.show()

# %%
model_training_flt = TrainModel(epoch = 100, filter=True)
# Out:
# 100%|██████████| 21837/21837 [00:38<00:00, 570.74it/s]

# %%
model_training_flt.train_model()
# Out:
# Epoch 1/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 101s 220ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.2030 - binary_accuracy: 0.7459 - loss: 2.0312 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.4382 - val_binary_accuracy: 0.7451 - val_loss: 1.9459
# Epoch 2/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 81s 198ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.4272 - binary_accuracy: 0.7459 - loss: 1.9301 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.4604 - val_binary_accuracy: 0.7451 - val_loss: 1.8711
# Epoch 3/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 88s 215ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.4446 - binary_accuracy: 0.7458 - loss: 1.8739 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.4709 - val_binary_accuracy: 0.7451 - val_loss: 1.8300
# Epoch 4/100
# ...

# %%
sns.relplot(data=pd.DataFrame(model_training_flt.history.history), kind='line', height=4, aspect=4)
plt.show()

# %%
model_training_flt_set = TrainModel(epoch = 100, filter=True, poles=5, upperCutoff = 10)
# Out:
# 100%|██████████| 21837/21837 [00:36<00:00, 601.01it/s]
# 2025-05-14 07:58:18.549337: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2025-05-14 07:58:18.549375: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2025-05-14 07:58:18.549378: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# 2025-05-14 07:58:18.549407: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-05-14 07:58:18.549420: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model_training_flt_set.train_model()
# Out:
# Epoch 1/100
# 2025-05-14 07:58:21.494292: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 101s 219ms/step - Precision: 0.7376 - Recall: 0.0017 - accuracy: 0.1941 - binary_accuracy: 0.7448 - loss: 2.0352 - val_Precision: 0.6267 - val_Recall: 0.0084 - val_accuracy: 0.4261 - val_binary_accuracy: 0.7460 - val_loss: 1.9353
# Epoch 2/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 86s 209ms/step - Precision: 0.5914 - Recall: 0.0038 - accuracy: 0.4089 - binary_accuracy: 0.7445 - loss: 1.9376 - val_Precision: 0.7292 - val_Recall: 0.0126 - val_accuracy: 0.4741 - val_binary_accuracy: 0.7472 - val_loss: 1.8588
# Epoch 3/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 82s 200ms/step - Precision: 0.6671 - Recall: 0.0069 - accuracy: 0.4509 - binary_accuracy: 0.7469 - loss: 1.8620 - val_Precision: 0.7363 - val_Recall: 0.0120 - val_accuracy: 0.4858 - val_binary_accuracy: 0.7471 - val_loss: 1.8055
# Epoch 4/100
# ...

# %%
sns.relplot(data=pd.DataFrame(model_training_flt_set.history.history), kind='line', height=4, aspect=4)
plt.show()

# %%
model_training_flt_set_ext = TrainModel(epoch = 100, filter=True, poles=5, upperCutoff = 5)
# Out:
# 100%|██████████| 21837/21837 [00:36<00:00, 593.06it/s]

# %%
model_training_flt_set_ext.train_model()
# Out:
# Epoch 1/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 99s 214ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.4533 - binary_accuracy: 0.7449 - loss: 2.0097 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.4476 - val_binary_accuracy: 0.7451 - val_loss: 1.9212
# Epoch 2/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 81s 198ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.4349 - binary_accuracy: 0.7446 - loss: 1.9208 - val_Precision: 1.0000 - val_Recall: 3.5932e-04 - val_accuracy: 0.4457 - val_binary_accuracy: 0.7452 - val_loss: 1.8483
# Epoch 3/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 84s 205ms/step - Precision: 0.4426 - Recall: 0.0025 - accuracy: 0.4465 - binary_accuracy: 0.7468 - loss: 1.8374 - val_Precision: 0.8407 - val_Recall: 0.0920 - val_accuracy: 0.4661 - val_binary_accuracy: 0.7641 - val_loss: 1.7749
# Epoch 4/100
# ...

# %%
sns.relplot(data=pd.DataFrame(model_training_flt_set_ext.history.history), kind='line', height=4, aspect=4)
plt.show()

# %%
model_training_flt_set_min = TrainModel(epoch = 100, filter=True, poles=5, upperCutoff = 20)
# Out:
# 100%|██████████| 21837/21837 [00:38<00:00, 571.07it/s]
# 2025-05-14 19:36:04.453943: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2025-05-14 19:36:04.453980: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2025-05-14 19:36:04.453983: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# 2025-05-14 19:36:04.454000: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-05-14 19:36:04.454010: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model_training_flt_set_min.train_model()
# Out:
# Epoch 1/100
# 2025-05-14 19:36:07.344533: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 98s 213ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.2776 - binary_accuracy: 0.7450 - loss: 2.0398 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.4437 - val_binary_accuracy: 0.7451 - val_loss: 1.9888
# Epoch 2/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 87s 213ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.4491 - binary_accuracy: 0.7464 - loss: 1.9677 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.4897 - val_binary_accuracy: 0.7451 - val_loss: 1.9273
# Epoch 3/100
# ...

# %%
sns.relplot(data=pd.DataFrame(model_training_flt_set_min.history.history), kind='line', height=4, aspect=4)
plt.show()

# %%
model_training_flt_set_min_2 = TrainModel(epoch = 100, filter=True, poles=5, upperCutoff = 30)
# Out:
# 100%|██████████| 21837/21837 [00:39<00:00, 550.43it/s]

# %%
model_training_flt_set_min_2.train_model()
# Out:
# Epoch 1/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 103s 221ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.3204 - binary_accuracy: 0.7464 - loss: 2.0212 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.4538 - val_binary_accuracy: 0.7451 - val_loss: 1.9667
# Epoch 2/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 87s 211ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.4467 - binary_accuracy: 0.7454 - loss: 1.9567 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.4654 - val_binary_accuracy: 0.7451 - val_loss: 1.9052
# Epoch 3/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 90s 220ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.4468 - binary_accuracy: 0.7449 - loss: 1.9180 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.4753 - val_binary_accuracy: 0.7451 - val_loss: 1.8669
# Epoch 4/100
# ...

# %%
sns.relplot(data=pd.DataFrame(model_training_flt_set_min_2.history.history), kind='line', height=4, aspect=4)
plt.show()

# %%
model_training_flt_set_25 = TrainModel(epoch = 100, filter=True, poles=5, upperCutoff = 25)
# Out:
# 100%|██████████| 21837/21837 [00:37<00:00, 590.08it/s]

# %%
model_training_flt_set_25.train_model()
# Out:
# Epoch 1/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 97s 209ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.4425 - binary_accuracy: 0.7435 - loss: 2.0326 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.4558 - val_binary_accuracy: 0.7451 - val_loss: 1.9702
# Epoch 2/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 80s 195ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.4412 - binary_accuracy: 0.7448 - loss: 1.9681 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.4634 - val_binary_accuracy: 0.7451 - val_loss: 1.9138
# Epoch 3/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 80s 194ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.4424 - binary_accuracy: 0.7447 - loss: 1.9270 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.4588 - val_binary_accuracy: 0.7451 - val_loss: 1.8852
# Epoch 4/100
# ...

# %%
sns.relplot(data=pd.DataFrame(model_training_flt_set_25.history.history), kind='line', height=4, aspect=4)
plt.show()
